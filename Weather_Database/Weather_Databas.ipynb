# %% [markdown]
# # Deliverable 1

# %%
# 1. Create a folder called Weather_Database.

# %%
# 2. Create a new Jupyter Notebook file to retrieve the weather data, and name it Weather_Database.ipynb.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# 4. Get the nearest city using the citipy module.

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
print(cities)
# Out:
# ['jabiru', 'grand river south east', 'arraial do cabo', 'mayya', 'puerto ayora', 'srednekolymsk', 'lagoa', 'ushuaia', 'rikitea', 'yellowknife', 'margate', 'naze', 'cape town', 'leningradskiy', 'walvis bay', 'dingle', 'east london', 'stonewall', 'punta arenas', 'castro', 'barentsburg', 'ballitoville', 'chuy', 'mahebourg', 'aklavik', 'port-gentil', 'bilma', 'mattru', 'avarua', 'ilulissat', 'hithadhoo', 'togur', 'pochutla', 'atuona', 'plouzane', 'gidam', 'mashhad', 'hovd', 'sterling', 'soyo', 'alta floresta', 'luderitz', 'illoqqortoormiut', 'port blair', 'huarmey', 'hobart', 'barrow', 'albany', 'itarema', 'pionerskiy', 'dzhalil', 'hilo', 'muskegon', 'bluff', 'faanui', 'tautira', 'victoria', 'pozo colorado', 'saldanha', 'bethel', 'butaritari', 'souillac', 'honningsvag', 'zeya', 'sur', 'hami', 'shingu', 'victor harbor', 'kruisfontein', 'airai', 'azar shahr', 'koboko', 'gat', 'warqla', 'nizhneyansk', 'kutum', 'lebu', 'belushya guba', 'college', 'mataura', 'fort-shevchenko', 'roald', 'ixtapa', 'taolanaro', 'chokurdakh', 'maceio', 'arman', 'jamestown', 'shihezi', 'port lincoln', 'padang', 'touros', 'kampar', 'karkaralinsk', 'lolua', 'busselton', 'hermanus', 'kralendijk', 'owando', 'maragogi', 'sao joao da barra', 'abaza', 'palkino', 'hagondange', 'ahipara', 'richards bay', 'ponta do sol', 'xingcheng', 'shimoda', 'longyearbyen', 'mao', 'yar-sale', 'lasa', 'upernavik', 'along', 'flinders', 'amderma', 'geraldton', 'vaini', 'kushiro', 'port alfred', 'tuktoyaktuk', 'talnakh', 'mys shmidta', 'gizo', 'ribeira grande', 'san lawrenz', 'newark', 'kodiak', 'georgetown', 'iskateley', 'poum', 'chara', 'boquira', 'kirakira', 'avera', 'ornskoldsvik', 'cherskiy', 'khatanga', 'hermiston', 'vila velha', 'caxias do sul', 'tsihombe', 'beringovskiy', 'ust-kan', 'yuci', 'torbay', 'channel-port aux basques', 'qaanaaq', 'szczecinek', 'adrar', 'riaba', 'kongoussi', 'la ronge', 'dudinka', 'berlevag', 'constitucion', 'muravlenko', 'manicore', 'sinkat', 'bossembele', 'sentyabrskiy', 'mareeba', 'pandaria', 'katsuura', 'huanren', 'warri', 'sao filipe', 'sitka', 'ruatoria', 'nioro', 'toguchin', 'haines junction', 'killybegs', 'mizdah', 'sabha', 'guajara-mirim', 'arlit', 'praia da vitoria', 'new norfolk', 'half moon bay', 'saleaula', 'inderborskiy', 'dumas', 'kapaa', 'farah', 'hamilton', 'moranbah', 'wulanhaote', 'port hardy', 'curup', 'tahoua', 'khotynets', 'azul', 'oranjemund', 'kloulklubed', 'les cayes', 'severo-kurilsk', 'thinadhoo', 'aitape', 'porto novo', 'san patricio', 'varadero', 'norsup', 'halifax', 'magdagachi', 'miguel hidalgo', 'kaeo', 'havoysund', 'demerval lobao', 'bengkulu', 'jalu', 'gardendale', 'christchurch', 'le vauclin', 'nynashamn', 'matamoros', 'havre-saint-pierre', 'alofi', 'iquitos', 'bambanglipuro', 'norman wells', 'guarda', 'santa fe', 'barroualie', 'bredasdorp', 'visnes', 'mar del plata', 'manta', 'batemans bay', 'ostrovnoy', 'port elizabeth', 'olafsvik', 'kargala', 'barra do garcas', 'santa cruz de tenerife', 'dikson', 'thompson', 'verkh-usugli', 'nikolskoye', 'provideniya', 'saint-philippe', 'vila franca do campo', 'kalemie', 'syedove', 'manakara', 'bondo', 'esperance', 'terra santa', 'dauphin', 'hasaki', 'ambon', 'tuatapere', 'laguna', 'danville', 'bhinmal', 'neuquen', 'akdagmadeni', 'barawe', 'sao felix do xingu', 'ust-tsilma', 'coihaique', 'palabuhanratu', 'saint-francois', 'mount gambier', 'venado tuerto', 'iqaluit', 'paralimni', 'martinez', 'kununurra', 'tinalmud', 'warrnambool', 'humaita', 'terrace', 'kirkwall', 'gwadar', 'iranshahr', 'lawton', 'gobabis', 'ardesen', 'yabrud', 'nicoya', 'hanna', 'faya', 'rawson', 'lompoc', 'caravelas', 'cabo san lucas', 'timmins', 'novo aripuana', 'akyab', 'da nang', 'saint anthony', 'anloga', 'ugoofaaru', 'contai', 'klaksvik', 'oktyabrskiy', 'kamenskoye', 'le mans', 'solsvik', 'mayskiy', 'liku', 'tambacounda', 'manzanillo', 'bambous virieux', 'saint george', 'karasburg', 'umm lajj', 'sinegorsk', 'attawapiskat', 'puerto el triunfo', 'lorengau', 'inhambane', 'manaure', 'ngukurr', 'grand gaube', 'dun ...

# %%
# 5. Perform an API call with the OpenWeatherMap.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
import json

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# 7. Retrieve the following information from the API call:

#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)
#Add the data to a new DataFrame.


# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | mayya
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | srednekolymsk
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | margate
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | walvis bay
# Processing Record 16 of Set 1 | dingle
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | stonewall
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | ballitoville
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | mahebourg
# Processing Record 25 of Set 1 | aklavik
# Processing Record 26 of Set 1 | port-gentil
# Processing Record 27 of Set 1 | bilma
# Processing Record 28 of Set 1 | mattru
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | ilulissat
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | togur
# Processing Record 33 of Set 1 | pochutla
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | plouzane
# Processing Record 36 of Set 1 | gidam
# Processing Record 37 of Set 1 | mashhad
# Processing Record 38 of Set 1 | hovd
# Processing Record 39 of Set 1 | sterling
# Processing Record 40 of Set 1 | soyo
# Processing Record 41 of Set 1 | alta floresta
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | port blair
# Processing Record 45 of Set 1 | huarmey
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | itarema
# Processing Record 50 of Set 1 | pionerskiy
# Processing Record 1 of Set 2 | dzhalil
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | muskegon
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | tautira
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | pozo colorado
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | honningsvag
# Processing Record 14 of Set 2 | zeya
# Processing Record 15 of Set 2 | sur
# Processing Record 16 of Set 2 | hami
# Processing Record 17 of Set 2 | shingu
# Processing Record 18 of Set 2 | victor harbor
# Processing Record 19 of Set 2 | kruisfontein
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | azar shahr
# City not found. Skipping...
# Processing Record 22 of Set 2 | koboko
# Processing Record 23 of Set 2 | gat
# Processing Record 24 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | kutum
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | fort-shevchenko
# Processing Record 32 of Set 2 | roald
# Processing Record 33 of Set 2 | ixtapa
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | maceio
# Processing Record 37 of Set 2 | arman
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | shihezi
# Processing Record 40 of Set 2 | port lincoln
# Processing Record 41 of Set 2 | padang
# Processing Record 42 of Set 2 | touros
# Processing Record 43 of Set 2 | kampar
# Processing Record 44 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | kralendijk
# Processing Record 49 of Set 2 | owando
# Processing Record 50 of Set 2 | maragogi
# Processing Record 1 of Set 3 | sao joao da barra
# Processing Record 2 of Set 3 | abaza
# Processing Record 3 of Set 3 | palkino
# Processing Record 4 of Set 3 | hagondange
# Processing Record 5 of Set 3 | ahipara
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | xingcheng
# Processing Record 9 of Set 3 | shimoda
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | mao
# Processing Record 12 of Set 3 | yar-sale
# Processing Record 13 of Set 3 | lasa
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | along
# Processing Record 16 of Set 3 | flinders
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | kushiro
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 3 | gizo
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | san lawrenz
# Processing Record 28 of Set 3 | newark
# Processing Record 29 of Set 3 | kodiak
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | iskateley
# Processing Record 32 of Set 3 | poum
# Processing Record 33 of Set 3 | chara
# Processing Record 34 of Set 3 | boquira
# Processing Record 35 of Set 3 | kirakira
# Processing Record 36 of Set 3 | avera
# Processing Record 37 of Set 3 | ornskoldsvik
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | hermiston
# Processing Record 41 of Set 3 | vila velha
# Processing Record 42 of Set 3 | caxias do sul
# Processing Record 43 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 3 | beringovskiy
# Processing Record 45 of Set 3 | ust-kan
# Processing Record 46 of Set 3 | yuci
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | channel-port aux basques
# Processing Record 49 of Set 3 | qaanaaq
# Processing Record 50 of Set 3 | szczecinek
# Processing Record 1 of Set 4 | adrar
# Processing Record 2 of Set 4 | riaba
# City not found. Skipping...
# Processing Record 3 of Set 4 | kongoussi
# Processing Record 4 of Set 4 | la ronge
# Processing Record 5 of Set 4 | dudinka
# Processing Record 6 of Set 4 | berlevag
# Processing Record 7 of Set 4 | constitucion
# Processing Record 8 of Set 4 | muravlenko
# Processing Record 9 of Set 4 | manicore
# Processing Record 10 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 4 | bossembele
# City not found. Skipping...
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | mareeba
# Processing Record 14 of Set 4 | pandaria
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | huanren
# Processing Record 17 of Set 4 | warri
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | sitka
# Processing Record 20 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 4 | nioro
# Processing Record 22 of Set 4 | toguchin
# Processing Record 23 of Set 4 | haines junction
# Processing Record 24 of Set 4 | killybegs
# Processing Record 25 of Set 4 | mizdah
# Processing Record 26 of Set 4 | sabha
# Processing Record 27 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 28 of Set 4 | arlit
# Processing Record 29 of Set 4 | praia da vitoria
# Processing Record 30 of Set 4 | new norfolk
# Processing Record 31 of Set 4 | half moon bay
# Processing Record 32 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 4 | dumas
# Processing Record 35 of Set 4 | kapaa
# Processing Record 36 of Set 4 | farah
# Processing Record 37 of Set 4 | hamilton
# Processing Record 38 of Set 4 | moranbah
# Processing Record 39 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 4 | port hardy
# Processing Record 41 of Set 4 | curup
# Processing Record 42 of Set 4 | tahoua
# Processing Record 43 of Set 4 | khotynets
# Processing Record 44 of Set 4 | azul
# Processing Record 45 of Set 4 | oranjemund
# Processing Record 46 of Set 4 | kloulklubed
# Processing Record 47 of Set 4 | les cayes
# Processing Record 48 of Set 4 | severo-kurilsk
# Processing Record 49 of Set 4 | thinadhoo
# Processing Record 50 of Set 4 | aitape
# Processing Record 1 of Set 5 | porto novo
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | varadero
# Processing Record 4 of Set 5 | norsup
# Processing Record 5 of Set 5 | halifax
# Processing Record 6 of Set 5 | magdagachi
# Processing Record 7 of Set 5 | miguel hidalgo
# Processing Record 8 of Set 5 | kaeo
# Processing Record 9 of Set 5 | havoysund
# Processing Record 10 of Set 5 | demerval lobao
# Processing Record 11 of Set 5 | bengkulu
# Processing Record 12 of Set 5 | jalu
# Processing Record 13 of Set 5 | gardendale
# Processing Record 14 of Set 5 | christchurch
# Processing Record 15 of Set 5 | le vauclin
# Processing Record 16 of Set 5 | nynashamn
# Processing Record 17 of Set 5 | matamoros
# Processing Record 18 of Set 5 | havre-saint-pierre
# Processing Record 19 of Set 5 | alofi
# Processing Record 20 of Set 5 | iquitos
# Processing Record 21 of Set 5 | bambanglipuro
# Processing Record 22 of Set 5 | norman wells
# Processing Record 23 of Set 5 | guarda
# Processing Record 24 of Set 5 | santa fe
# Processing Record 25 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 26 of Set 5 | bredasdorp
# Processing Record 27 of Set 5 | visnes
# Processing Record 28 of Set 5 | mar del plata
# Processing Record 29 of Set 5 | manta
# Processing Record 30 of Set 5 | batemans bay
# Processing Record 31 of Set 5 | ostrovnoy
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | olafsvik
# Processing Record 34 of Set 5 | kargala
# Processing Record 35 of Set 5 | barra do garcas
# Processing Record 36 of Set 5 | santa cruz de tenerife
# Processing Record 37 of Set 5 | dikson
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | verkh-usugli
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | provideniya
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | vila franca do campo
# Processing Record 44 of Set 5 | kalemie
# Processing Record 45 of Set 5 | syedove
# Processing Record 46 of Set 5 | manakara
# Processing Record 47 of Set 5 | bondo
# Processing Record 48 of Set 5 | esperance
# Processing Record 49 of Set 5 | terra santa
# Processing Record 50 of Set 5 | dauphin
# Processing Record 1 of Set 6 | hasaki
# Processing Record 2 of Set 6 | ambon
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | laguna
# Processing Record 5 of Set 6 | danville
# Processing Record 6 of Set 6 | bhinmal
# Processing Record 7 of Set 6 | neuquen
# Processing Record 8 of Set 6 | akdagmadeni
# Processing Record 9 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 6 | sao felix do xingu
# Processing Record 11 of Set 6 | ust-tsilma
# Processing Record 12 of Set 6 | coihaique
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-francois
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | venado tuerto
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | paralimni
# Processing Record 19 of Set 6 | martinez
# Processing Record 20 of Set 6 | kununurra
# Processing Record 21 of Set 6 | tinalmud
# Processing Record 22 of Set 6 | warrnambool
# Processing Record 23 of Set 6 | humaita
# Processing Record 24 of Set 6 | terrace
# Processing Record 25 of Set 6 | kirkwall
# Processing Record 26 of Set 6 | gwadar
# Processing Record 27 of Set 6 | iranshahr
# Processing Record 28 of Set 6 | lawton
# Processing Record 29 of Set 6 | gobabis
# Processing Record 30 of Set 6 | ardesen
# Processing Record 31 of Set 6 | yabrud
# Processing Record 32 of Set 6 | nicoya
# Processing Record 33 of Set 6 | hanna
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | rawson
# Processing Record 36 of Set 6 | lompoc
# Processing Record 37 of Set 6 | caravelas
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | timmins
# Processing Record 40 of Set 6 | novo aripuana
# Processing Record 41 of Set 6 | akyab
# Processing Record 42 of Set 6 | da nang
# Processing Record 43 of Set 6 | saint anthony
# Processing Record 44 of Set 6 | anloga
# Processing Record 45 of Set 6 | ugoofaaru
# Processing Record 46 of Set 6 | contai
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | oktyabrskiy
# Processing Record 49 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | le mans
# Processing Record 1 of Set 7 | solsvik
# City not found. Skipping...
# Processing Record 2 of Set 7 | mayskiy
# Processing Record 3 of Set 7 | liku
# Processing Record 4 of Set 7 | tambacounda
# Processing Record 5 of Set 7 | manzanillo
# Processing Record 6 of Set 7 | bambous virieux
# Processing Record 7 of Set 7 | saint george
# Processing Record 8 of Set 7 | karasburg
# Processing Record 9 of Set 7 | umm lajj
# Processing Record 10 of Set 7 | sinegorsk
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | puerto el triunfo
# Processing Record 13 of Set 7 | lorengau
# Processing Record 14 of Set 7 | inhambane
# Processing Record 15 of Set 7 | manaure
# Processing Record 16 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 7 | grand gaube
# Processing Record 18 of Set 7 | dunedin
# Processing Record 19 of Set 7 | pierre
# Processing Record 20 of Set 7 | qixingtai
# Processing Record 21 of Set 7 | san carlos
# Processing Record 22 of Set 7 | plettenberg bay
# Processing Record 23 of Set 7 | san martin
# Processing Record 24 of Set 7 | honiara
# Processing Record 25 of Set 7 | nago
# Processing Record 26 of Set 7 | burnie
# Processing Record 27 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 7 | muroto
# Processing Record 29 of Set 7 | bilibino
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 7 | ambanja
# Processing Record 32 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 7 | poplar bluff
# Processing Record 34 of Set 7 | bodrum
# Processing Record 35 of Set 7 | ixtacomitan
# Processing Record 36 of Set 7 | lata
# Processing Record 37 of Set 7 | naliya
# Processing Record 38 of Set 7 | jurm
# Processing Record 39 of Set 7 | brae
# Processing Record 40 of Set 7 | kristinehamn
# Processing Record 41 of Set 7 | nanakuli
# Processing Record 42 of Set 7 | dhuri
# Processing Record 43 of Set 7 | leshukonskoye
# Processing Record 44 of Set 7 | emilio carranza
# Processing Record 45 of Set 7 | zhigansk
# Processing Record 46 of Set 7 | denizli
# Processing Record 47 of Set 7 | kantang
# Processing Record 48 of Set 7 | heinola
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | los llanos de aridane
# Processing Record 1 of Set 8 | el tigre
# Processing Record 2 of Set 8 | broome
# Processing Record 3 of Set 8 | tiksi
# Processing Record 4 of Set 8 | tasiilaq
# Processing Record 5 of Set 8 | saskylakh
# Processing Record 6 of Set 8 | carnarvon
# Processing Record 7 of Set 8 | semikarakorsk
# Processing Record 8 of Set 8 | puerto suarez
# Processing Record 9 of Set 8 | isabela
# Processing Record 10 of Set 8 | nizhniy kuranakh
# Processing Record 11 of Set 8 | vasteras
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | general pico
# Processing Record 15 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 8 | come
# Processing Record 17 of Set 8 | kangaatsiaq
# Processing Record 18 of Set 8 | sisimiut
# Processing Record 19 of Set 8 | slonim
# Processing Record 20 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 8 | bogorodskoye
# Processing Record 22 of Set 8 | kyabe
# Processing Record 23 of Set 8 | namibe
# Processing Record 24 of Set 8 | mouila
# Processing Record 25 of Set 8 | tiznit
# Processing Record 26 of Set 8 | banda aceh
# Processing Record 27 of Set 8 | maple creek
# Processing Record 28 of Set 8 | kolo
# Processing Record 29 of Set 8 | tari
# Processing Record 30 of Set 8 | penzance
# Processing Record 31 of Set 8 | yulara
# Processing Record 32 of Set 8 | bairiki
# Processing Record 33 of Set 8 | coquimbo
# Processing Record 34 of Set 8 | bull savanna
# Processing Record 35 of Set 8 | rosetown
# Processing Record 36 of Set 8 | palana
# Processing Record 37 of Set 8 | tezu
# Processing Record 38 of Set 8 | marystown
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | hayden
# Processing Record 41 of Set 8 | acushnet
# Processing Record 42 of Set 8 | nouadhibou
# Processing Record 43 of Set 8 | miracema
# Processing Record 44 of Set 8 | anchorage
# Processing Record 45 of Set 8 | sechura
# Processing Record 46 of Set 8 | port hawkesbury
# Processing Record 47 of Set 8 | brownsville
# Processing Record 48 of Set 8 | pitimbu
# Processing Record 49 of Set 8 | hervey bay
# Processing Record 50 of Set 8 | bereznik
# Processing Record 1 of Set 9 | diapaga
# Processing Record 2 of Set 9 | sao miguel do araguaia
# Processing Record 3 of Set 9 | belyy yar
# Processing Record 4 of Set 9 | sinnar
# Processing Record 5 of Set 9 | kwekwe
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | dawei
# Processing Record 8 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 9 | taitung
# Processing Record 10 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 9 | tura
# Processing Record 12 of Set 9 | moroto
# Processing Record 13 of Set 9 | howard springs
# Processing Record 14 of Set 9 | rapid valley
# Processing Record 15 of Set 9 | ginda
# Processing Record 16 of Set 9 | tabou
# Processing Record 17 of Set 9 | jumla
# Processing Record 18 of Set 9 | bodden town
# Processing Record 19 of Set 9 | cidreira
# Processing Record 20 of Set 9 | saint-marc-des-carrieres
# Processing Record 21 of Set 9 | mitu
# Processing Record 22 of Set 9 | straumen
# Processing Record 23 of Set 9 | kaitangata
# Processing Record 24 of Set 9 | mocuba
# Processing Record 25 of Set 9 | san cristobal
# Processing Record 26 of Set 9 | salinopolis
# Processing Record 27 of Set 9 | mwinilunga
# Processing Record 28 of Set 9 | turan
# Processing Record 29 of Set 9 | puerto carreno
# Processing Record 30 of Set 9 | nayoro
# Processing Record 31 of Set 9 | sao francisco
# Processing Record 32 of Set 9 | horadiz
# Processing Record 33 of Set 9 | vestmannaeyjar
# Processing Record 34 of Set 9 | luzhou
# Processing Record 35 of Set 9 | shahrud
# Processing Record 36 of Set 9 | miraflores
# Processing Record 37 of Set 9 | namatanai
# Processing Record 38 of Set 9 | narasannapeta
# Processing Record 39 of Set 9 | korla
# Processing Record 40 of Set 9 | ancud
# Processing Record 41 of Set 9 | juneau
# Processing Record 42 of Set 9 | clyde river
# Processing Record 43 of Set 9 | mossendjo
# Processing Record 44 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 9 | kant
# Processing Record 48 of Set 9 | inuvik
# Processing Record 49 of Set 9 | yarada
# Processing Record 50 of Set 9 | indian head
# Processing Record 1 of Set 10 | tatui
# Processing Record 2 of Set 10 | kamenka
# Processing Record 3 of Set 10 | ariquemes
# Processing Record 4 of Set 10 | abong mbang
# Processing Record 5 of Set 10 | sorland
# Processing Record 6 of Set 10 | dawson creek
# Processing Record 7 of Set 10 | mayo
# Processing Record 8 of Set 10 | khovu-aksy
# Processing Record 9 of Set 10 | berdigestyakh
# Processing Record 10 of Set 10 | scottsbluff
# Processing Record 11 of Set 10 | sola
# Processing Record 12 of Set 10 | novikovo
# Processing Record 13 of Set 10 | camacha
# Processing Record 14 of Set 10 | kahului
# Processing Record 15 of Set 10 | ha giang
# Processing Record 16 of Set 10 | okha
# Processing Record 17 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 10 | kalengwa
# Processing Record 19 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 20 of Set 10 | deputatskiy
# Processing Record 21 of Set 10 | uglegorskiy
# Processing Record 22 of Set 10 | awbari
# Processing Record 23 of Set 10 | moerai
# Processing Record 24 of Set 10 | broken hill
# Processing Record 25 of Set 10 | altay
# Processing Record 26 of Set 10 | kemijarvi
# Processing Record 27 of Set 10 | sambava
# Processing Record 28 of Set 10 | hastings
# Processing Record 29 of Set 10 | tessalit
# Processing Record 30 of Set 10 | coahuayana
# Processing Record 31 of Set 10 | parras
# City not found. Skipping...
# Processing Record 32 of Set 10 | ziro
# Processing Record 33 of Set 10 | the valley
# Processing Record 34 of Set 10 | manaquiri
# Processing Record 35 of Set 10 | chapais
# Processing Record 36 of Set 10 | erenhot
# Processing Record 37 of Set 10 | ampanihy
# Processing Record 38 of Set 10 | putnok
# Processing Record 39 of Set 10 | saint-augustin
# Processing Record 40 of Set 10 | narsaq
# Processing Record 41 of Set 10 | erzin
# Processing Record 42 of Set 10 | megion
# Processing Record 43 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 44 of Set 10 | praia
# Processing Record 45 of Set 10 | okhotsk
# Processing Record 46 of Set 10 | oktyabrskoye
# Processing Record 47 of Set 10 | paamiut
# Processing Record 48 of Set 10 | shache
# Processing Record 49 of Set 10 | alyangula
# Processing Record 50 of Set 10 | mehriz
# Processing Record 1 of Set 11 | tripoli
# Processing Record 2 of Set 11 | fukue
# Processing Record 3 of Set 11 | kieta
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | godfrey
# Processing Record 6 of Set 11 | saint-pierre
# Processing Record 7 of Set 11 | kumluca
# Processing Record 8 of Set 11 | shahr-e babak
# Processing Record 9 of Set 11 | cape coast
# Processing Record 10 of Set 11 | gotsu
# Processing Record 11 of Set 11 | escanaba
# Processing Record 12 of Set 11 | greenfield
# Processing Record 13 of Set 11 | pisco
# Processing Record 14 of Set 11 | muktagachha
# City not found. Skipping...
# Processing Record 15 of Set 11 | teknaf
# Processing Record 16 of Set 11 | matadi
# Processing Record 17 of Set 11 | bandarbeyla
# Processing Record 18 of Set 11 | husavik
# Processing Record 19 of Set 11 | kavaratti
# Processing Record 20 of Set 11 | andijon
# Processing Record 21 of Set 11 | fuyu
# Processing Record 22 of Set 11 | cuamba
# Processing Record 23 of Set 11 | codrington
# Processing Record 24 of Set 11 | moose factory
# Processing Record 25 of Set 11 | chernogorsk
# Processing Record 26 of Set 11 | simao
# Processing Record 27 of Set 11 | uwajima
# Processing Record 28 of Set 11 | bedele
# Processing Record 29 of Set 11 | waipawa
# Processing Record 30 of Set 11 | sanchazi
# Processing Record 31 of Set 11 | bukama
# Processing Record 32 of Set 11 | satellite beach
# Processing Record 33 of Set 11 | portlethen
# Processing Record 34 of Set 11 | fort nelson
# Processing Record 35 of Set 11 | alice springs
# Processing Record 36 of Set 11 | khani
# Processing Record 37 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 11 | bhola
# Processing Record 39 of Set 11 | malakal
# Processing Record 40 of Set 11 | prince rupert
# Processing Record 41 of Set 11 | anuradhapura
# Processing Record 42 of Set 11 | vao
# Processing Record 43 of Set 11 | hakvik
# City not found. Skipping...
# Processing Record 44 of Set 11 | craig
# Processing Record 45 of Set 11 | nuuk
# Processing Record 46 of Set 11 | hailar
# Processing Record 47 of Set 11 | patea
# Processing Record 48 of Set 11 | merano
# Processing Record 49 of Set 11 | roura
# Processing Record 50 of Set 11 | teahupoo
# Processing Record 1 of Set 12 | camopi
# Processing Record 2 of Set 12 | wattegama
# Processing Record 3 of Set 12 | quatre cocos
# Processing Record 4 of Set 12 | artvin
# Processing Record 5 of Set 12 | abu dhabi
# Processing Record 6 of Set 12 | zhuanghe
# Processing Record 7 of Set 12 | baruun-urt
# Processing Record 8 of Set 12 | velizh
# Processing Record 9 of Set 12 | marathon
# Processing Record 10 of Set 12 | oriximina
# Processing Record 11 of Set 12 | la paz
# Processing Record 12 of Set 12 | planadas
# Processing Record 13 of Set 12 | carcassonne
# Processing Record 14 of Set 12 | severodvinsk
# Processing Record 15 of Set 12 | susanville
# Processing Record 16 of Set 12 | jaciara
# Processing Record 17 of Set 12 | san policarpo
# Processing Record 18 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 12 | ranfurly
# Processing Record 20 of Set 12 | usak
# Processing Record 21 of Set 12 | zeven
# Processing Record 22 of Set 12 | waingapu
# Processing Record 23 of Set 12 | kampene
# Processing Record 24 of Set 12 | sukhobuzimskoye
# Processing Record 25 of Set 12 | palu
# Processing Record 26 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 12 | mukhen
# Processing Record 28 of Set 12 | kulhudhuffushi
# Processing Record 29 of Set 12 | necochea
# Processing Record 30 of Set 12 | soc trang
# Processing Record 31 of Set 12 | russell
# Processing Record 32 of Set 12 | george
# Processing Record 33 of Set 12 | taltal
# Processing Record 34 of Set 12 | goderich
# Processing Record 35 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 12 | copperas cove
# Processing Record 37 of Set 12 | harrisburg
# Processing Record 38 of Set 12 | warman
# Processing Record 39 of Set 12 | ilhabela
# Processing Record 40 of Set 12 | utica
# Processing Record 41 of Set 12 | bonnyville
# Processing Record 42 of Set 12 | kudahuvadhoo
# Processing Record 43 of Set 12 | toora-khem
# Processing Record 44 of Set 12 | yerbogachen
# Processing Record 45 of Set 12 | karpathos
# Processing Record 46 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 47 of Set 12 | illapel
# Processing Record 48 of Set 12 | hofn
# Processing Record 49 of Set 12 | turbat
# Processing Record 50 of Set 12 | labuhan
# Processing Record 1 of Set 13 | anadyr
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | bam
# Processing Record 4 of Set 13 | acarau
# Processing Record 5 of Set 13 | viransehir
# Processing Record 6 of Set 13 | lindi
# Processing Record 7 of Set 13 | samarai
# Processing Record 8 of Set 13 | puerto madryn
# Processing Record 9 of Set 13 | safranbolu
# Processing Record 10 of Set 13 | omboue
# Processing Record 11 of Set 13 | dakoro
# Processing Record 12 of Set 13 | belaya gora
# Processing Record 13 of Set 13 | komsomolskiy
# Processing Record 14 of Set 13 | patria
# Processing Record 15 of Set 13 | amahai
# Processing Record 16 of Set 13 | kandrian
# Processing Record 17 of Set 13 | tarata
# Processing Record 18 of Set 13 | cartagena
# Processing Record 19 of Set 13 | burley
# Processing Record 20 of Set 13 | acapulco
# Processing Record 21 of Set 13 | nemuro
# Processing Record 22 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 13 | isangel
# Processing Record 24 of Set 13 | sao francisco do conde
# Processing Record 25 of Set 13 | maroantsetra
# Processing Record 26 of Set 13 | nanortalik
# Processing Record 27 of Set 13 | jiayuguan
# Processing Record 28 of Set 13 | iracoubo
# Processing Record 29 of Set 13 | berdyuzhye
# City not found. Skipping...
# Processing Record 30 of Set 13 | port hedland
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | petauke
# Processing Record 33 of Set 13 | doba
# Processing Record 34 of Set 13 | abashiri
# Processing Record 35 of Set 13 | gamba
# Processing Record 36 of Set 13 | yelizovo
# Processing Record 37 of Set 13 | atherton
# Processing Record 38 of Set 13 | la rioja
# Processing Record 39 of Set 13 | rumphi
# Processing Record 40 of Set 13 | miguel auza
# Processing Record 41 of Set 13 | trinidad
# Processing Record 42 of Set 13 | padre paraiso
# Processing Record 43 of Set 13 | jiwani
# Processing Record 44 of Set 13 | grindavik
# Processing Record 45 of Set 13 | yumen
# Processing Record 46 of Set 13 | turayf
# Processing Record 47 of Set 13 | labrea
# Processing Record 48 of Set 13 | pangai
# Processing Record 49 of Set 13 | saint-joseph
# Processing Record 50 of Set 13 | kato soulion
# Processing Record 1 of Set 14 | oum hadjer
# Processing Record 2 of Set 14 | bagdarin
# Processing Record 3 of Set 14 | mikkeli
# Processing Record 4 of Set 14 | bonavista
# Processing Record 5 of Set 14 | murray bridge
# Processing Record 6 of Set 14 | portland
# Processing Record 7 of Set 14 | arosa
# Processing Record 8 of Set 14 | nyurba
# Processing Record 9 of Set 14 | nantucket
# Processing Record 10 of Set 14 | pevek
# Processing Record 11 of Set 14 | vanavara
# Processing Record 12 of Set 14 | ulaanbaatar
# Processing Record 13 of Set 14 | murgab
# Processing Record 14 of Set 14 | aldan
# Processing Record 15 of Set 14 | fortuna
# Processing Record 16 of Set 14 | uk
# City not found. Skipping...
# Processing Record 17 of Set 14 | zhezkazgan
# Processing Record 18 of Set 14 | cururupu
# Processing Record 19 of Set 14 | karratha
# Processing Record 20 of Set 14 | nuevo progreso
# Processing Record 21 of Set 14 | noumea
# Processing Record 22 of Set 14 | kuah
# Processing Record 23 of Set 14 | inirida
# Processing Record 24 of Set 14 | great bend
# Processing Record 25 of Set 14 | billings
# Processing Record 26 of Set 14 | sosnovo-ozerskoye
# Processing Record 27 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 14 | bermejo
# Processing Record 29 of Set 14 | te anau
# Processing Record 30 of Set 14 | colares
# Processing Record 31 of Set 14 | bulawayo
# Processing Record 32 of Set 14 | kalianget
# Processing Record 33 of Set 14 | niquelandia
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | xiaoweizhai
# Processing Record 36 of Set 14 | kindu
# Processing Record 37 of Set 14 | axim
# Processing Record 38 of Set 14 | suwannaphum
# Processing Record 39 of Set 14 | shevchenkove
# Processing Record 40 of Set 14 | miranda
# Processing Record 41 of Set 14 | yaan
# Processing Record 42 of Set 14 | zaplyusye
# City not found. Skipping...
# Processing Record 43 of Set 14 | dzhebariki-khaya
# Processing Record 44 of Set 14 | maniwaki
# Processing Record 45 of Set 14 | rantauprapat
# Processing Record 46 of Set 14 | bastia
# Processing Record 47 of Set 14 | bahia honda
# Processing Record 48 of Set 14 | black river
# Processing Record 49 of Set 14 | ayagoz
# Processing Record 50 of Set 14 | sobolevo
# Processing Record 1 of Set 15 | skjervoy
# Processing Record 2 of Set 15 | ponta delgada
# Processing Record 3 of Set 15 | garissa
# Processing Record 4 of Set 15 | basoda
# Processing Record 5 of Set 15 | muros
# Processing Record 6 of Set 15 | dahuk
# Processing Record 7 of Set 15 | zheshart
# Processing Record 8 of Set 15 | reinach
# Processing Record 9 of Set 15 | praya
# Processing Record 10 of Set 15 | bogo
# Processing Record 11 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 15 | manoel urbano
# Processing Record 13 of Set 15 | timberlake
# Processing Record 14 of Set 15 | argentan
# Processing Record 15 of Set 15 | manggar
# Processing Record 16 of Set 15 | phillaur
# Processing Record 17 of Set 15 | vardo
# Processing Record 18 of Set 15 | mahajanga
# Processing Record 19 of Set 15 | palmer
# Processing Record 20 of Set 15 | mercedes
# Processing Record 21 of Set 15 | avdon
# Processing Record 22 of Set 15 | tual
# Processing Record 23 of Set 15 | shenjiamen
# Processing Record 24 of Set 15 | kango
# Processing Record 25 of Set 15 | quzhou
# Processing Record 26 of Set 15 | ayutthaya
# Processing Record 27 of Set 15 | rehoboth
# Processing Record 28 of Set 15 | jibuti
# Processing Record 29 of Set 15 | uberlandia
# Processing Record 30 of Set 15 | vigeland
# Processing Record 31 of Set 15 | wahiawa
# Processing Record 32 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 34 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 15 | moron
# Processing Record 36 of Set 15 | springdale
# Processing Record 37 of Set 15 | stornoway
# Processing Record 38 of Set 15 | jinka
# Processing Record 39 of Set 15 | lucea
# Processing Record 40 of Set 15 | henties bay
# Processing Record 41 of Set 15 | birjand
# Processing Record 42 of Set 15 | fairbanks
# Processing Record 43 of Set 15 | santa catarina
# Processing Record 44 of Set 15 | arshan
# Processing Record 45 of Set 15 | campobasso
# Processing Record 46 of Set 15 | sajanan
# Processing Record 47 of Set 15 | nizhniy odes
# Processing Record 48 of Set 15 | urengoy
# Processing Record 49 of Set 15 | adana
# Processing Record 50 of Set 15 | eyrarbakki
# Processing Record 1 of Set 16 | el dorado
# Processing Record 2 of Set 16 | virginia beach
# Processing Record 3 of Set 16 | rocha
# Processing Record 4 of Set 16 | borovskoy
# Processing Record 5 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 16 | kempsey
# Processing Record 7 of Set 16 | skibbereen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     77.00        78           0
# 1            Mayya  61.7333  130.2811    -58.00        51          90
# 2     Puerto Ayora  -0.7393  -90.3518     80.60        69          75
# 3    Srednekolymsk  67.4500  153.6833    -41.10        81          40
# 4            Lagoa  39.0500  -27.9833     62.04        82          80
# 5          Ushuaia -54.8000  -68.3000     55.40        71          75
# 6          Rikitea -23.1203 -134.9692     78.96        74          15
# 7      Yellowknife  62.4560 -114.3525      1.40        85          90
# 8          Margate  51.3813    1.3862     39.99        79          96
# 9             Naze  28.3667  129.4833     50.00        81          40
#
#    Wind Speed Country Current Description                 Date
# 0       17.27      BR           clear sky  2021-01-17 23:00:09
# 1        4.63      RU                 fog  2021-01-17 23:03:19
# 2       17.27      EC       broken clouds  2021-01-17 23:03:19
# 3        3.00      RU    scattered clouds  2021-01-17 23:03:19
# 4       26.84      PT          light rain  2021-01-17 23:02:34
# 5        3.44      AR       broken clouds  2021-01-17 22:59:04
# 6       14.05      PF          few clouds  2021-01-17 23:03:20
# 7        4.61      CA                mist  2021-01-17 23:01:19
# 8        1.99      GB     overcast clouds  2021-01-17 23:00:39
# 9       10.36      JP    scattered clouds  2021-01-17 23:03:20

# %%
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# %%
city_data_df = city_data_df[new_column_order]

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
